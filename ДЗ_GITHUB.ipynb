# %%
# !git clone https://github.com/Garmonik/cvr_course.git
# Out:
# Cloning into 'cvr_course'...
# remote: Enumerating objects: 528, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 528 (delta 6), reused 1 (delta 0), pack-reused 514
# Receiving objects: 100% (528/528), 60.70 MiB | 25.45 MiB/s, done.
# Resolving deltas: 100% (124/124), done.
# Updating files: 100% (232/232), done.

# %%
cd cvr_course
# Out:
# /content/cvr_course/cvr_course/cvr_course/cvr_course/cvr_course

# %%
ls -la
# Out:
# total 36
# drwxr-xr-x 7 root root 4096 Feb 18 20:40 ./
# drwxr-xr-x 8 root root 4096 Feb 18 20:40 ../
# drwxr-xr-x 3 root root 4096 Feb 18 20:40 data/
# drwxr-xr-x 8 root root 4096 Feb 18 20:41 .git/
# -rw-r--r-- 1 root root  705 Feb 18 20:40 .gitignore
# drwxr-xr-x 2 root root 4096 Feb 18 20:40 .img/
# drwxr-xr-x 4 root root 4096 Feb 18 20:40 notebooks/
# drwxr-xr-x 2 root root 4096 Feb 18 20:41 presentations/
# -rw-r--r-- 1 root root  280 Feb 18 20:40 README.md

# %%
# !git branch update_readme

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/cvr_course/cvr_course/cvr_course/cvr_course/cvr_course/.git/

# %%
# !git checkout update_readme
# Out:
# Switched to branch 'update_readme'

# %%
# !git log
# Out:
# commit de02273bf72226b4938f4e362e2f405310fd0bfd (HEAD -> update_readme, origin/main, origin/HEAD, main)
# Merge: 607bfe6 47a23a2
# Author: Vladimir Lekhterev <44276006+tndrd@users.noreply.github.com>
# Date:   Thu Feb 9 14:26:11 2023 +0300
#
#     Merge pull request #27 from lekhterevvv/main
#
#     Fix "Open in Colab" button
#
# commit 47a23a210c15bebfd98cc1831615e415318f160b
# Author: lekhterevvv <123244943+lekhterevvv@users.noreply.github.com>
# Date:   Thu Feb 9 14:24:13 2023 +0300
#
#     Fix button
#
# commit f2ad3fb498fb88f12bb45b72f2479ed5f69773d6
# Author: lekhterevvv <123244943+lekhterevvv@users.noreply.github.com>
# Date:   Thu Feb 9 14:20:46 2023 +0300
#
#     FIx button
#
# commit 607bfe62c8a3f71e3709e7d3f44044b3ad1ca2fc
# Merge: 5d1ebed ac0c4c3
# Author: Vladimir Lekhterev <44276006+tndrd@users.noreply.github.com>
# Date:   Thu Feb 9 13:03:27 2023 +0300
#
#     Merge pull request #26 from lekhterevvv/main
#
#     Rewrite github sem 1
#
# ...

# %%
# !cat README.md
# Out:
# # Computer Vision in Robotics
#
# <img src="./.img/logo_for_form.png" height="350" />
#
#
# Visit our site <https://www.starkitrobots.com/cvr> to check content.
# Course is online and will be carried out on our *[YouTube chanel](https://www.youtube.com/channel/UC0QPJgfg17wCqf4-hG_A5OA)*.

# %%
# !echo "Добавить одну строчку в README.md" >> README.md

# %%
# !cat README.md
# Out:
# # Computer Vision in Robotics
#
# <img src="./.img/logo_for_form.png" height="350" />
#
#
# Visit our site <https://www.starkitrobots.com/cvr> to check content.
# Course is online and will be carried out on our *[YouTube chanel](https://www.youtube.com/channel/UC0QPJgfg17wCqf4-hG_A5OA)*.
# Добавить одну строчку в README.md

# %%
# !git add --all

# %%
# !git config --global user.email "markkolyaditch@yandex.ru"
# !git config --global user.name "Garmonik"
# !git commit -m "Update README."
# Out:
# [update_readme 107f2cb] Update README.
#  1 file changed, 1 insertion(+)

# %%
# !git remote add origin-psk https://Garmonik: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@github.com/Garmonik/cvr_course.git

# %%
# !git push origin-psk update_readme
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 350 bytes | 350.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# remote:
# remote: Create a pull request for 'update_readme' on GitHub by visiting:
# remote:      https://github.com/Garmonik/cvr_course/pull/new/update_readme
# remote:
# To https://github.com/Garmonik/cvr_course.git
#  * [new branch]      update_readme -> update_readme

# %%
# !git checkout develop
# !git merge update_readme
# Out:
# Branch 'develop' set up to track remote branch 'develop' from 'origin'.
# Switched to a new branch 'develop'
# Updating 85a8f0a..107f2cb
# Fast-forward
#  README.md                                          |     1 +
#  .../imgs/arrow/vlcsnap-2020-10-21-18h01m22s212.png |   Bin 0 -> 396905 bytes
#  .../imgs/arrow/vlcsnap-2020-10-21-18h01m27s294.png |   Bin 0 -> 349708 bytes
#  .../imgs/arrow/vlcsnap-2020-10-21-18h01m29s941.png |   Bin 0 -> 358518 bytes
#  .../imgs/arrow/vlcsnap-2020-10-21-18h01m33s362.png |   Bin 0 -> 336322 bytes
#  .../imgs/arrow/vlcsnap-2020-10-21-18h01m36s056.png |   Bin 0 -> 316925 bytes
#  .../imgs/arrow/vlcsnap-2020-10-21-18h01m41s874.png |   Bin 0 -> 312812 bytes
#  .../imgs/arrow/vlcsnap-2020-10-21-18h01m44s163.png |   Bin 0 -> 334378 bytes
#  .../imgs/arrow/vlcsnap-2020-10-21-18h01m46s644.png |   Bin 0 -> 314245 bytes
#  .../imgs/arrow/vlcsnap-2020-10-21-18h01m49s487.png |   Bin 0 -> 377742 bytes
# ...

# %%
# !git log --oneline --graph
# Out:
# * 107f2cb (HEAD -> develop, origin-psk/update_readme, update_readme) Update README.
# *   de02273 (origin/main, origin/HEAD, main) Merge pull request #27 from lekhterevvv/main
# |\
# | * 47a23a2 Fix button
# | * f2ad3fb FIx button
# |/
# *   607bfe6 Merge pull request #26 from lekhterevvv/main
# |\
# | * ac0c4c3 Rewrite github sem 1
# |/
# * 5d1ebed Fixed lightning bug and triangle ordering bug
# * 53975e1 Removed second problem from hw4. Modified first problem
# * 43d289b add loc hm
# *   41da54b Merge pull request #23 from kefir8888/main
# |\
# | * 4fedfe8 Changed hw name
# | *   4f121c8 Merge pull request #3 from StarkitRobots/main
# | |\
# | |/
# |/|
# * | 23f57ce Added seminar on architecture
# * |   58c0554 Merge pull request #15 from kefir8888/develop
# |\ \
# | * | 48266bc Cleared cells output
# | * | da1031f Added seminar on SLAM
# | * |   eb6d211 Merge branch 'develop' of https://github.com/kefir8888/cvr_course into develop
# | |\ \
# | * | | 3e66a6c Added 5 hw
# ...

# %%
# !git checkout main
# !git merge develop
